# %%
from operator import truediv

#check if a number is positive
x = 5
if x > 2:
   print ("five is positive")
# Out:
# five is positive

# %%
#check if a person is an adult
age=20
if age >=18:
    print ("the person is adult")
# Out:
# the person is adult

# %%
#print a message is its raining
raining = True
if raining:
    print ("take an umbrella")
# Out:
# take an umbrella

# %%
#check if a fruit is apple
fruit = "apple"
if fruit == "apple":
    print ("the fruit is apple")
# Out:
# the fruit is apple

# %%
#check if temperature is hot
temperature = 80
if temperature >= 30:
    print ("temp is hot")
# Out:
# temp is hot

# %%
#check if a number is even
number = 10
if 10 % 2 ==0:
    print ("number is even")
# Out:
# number is even

# %%
#check if name starts with A
name = "Ali"
if name.startswith ("A"):
    print ("your name starts with A")
# Out:
# your name starts with A

# %%
#check if speed is over 100
speed = 100
if speed >= 100:
    print ("speed is over 100")
# Out:
# speed is over 100

# %%
# two times indented with if
x = 30
if x > 10:
    if x < 40:
       print ("x is a number between 10 and 40")
# Out:
# x is a number between 10 and 40

# %%
#with if and else
# Even or odd
num = 7
if num % 2 == 0:
    print ("num is even")
else:
    print ("num is odd")
# Out:
# num is odd

# %%
#check if its raining
raining = False
if raining:
    print ("you need an umbrella")
else:
    print ("you do not need an umbrella")
# Out:
# you do not need an umbrella

# %%
#check if  a person is adult or child
person_age = input ("what is your age")
person_age = int (person_age)
if person_age >= 18:
    print ("the person is an adult")
else:
    print ("the person is not an adult")
# Out:
# the person is not an adult

# %%
#temperature check
temperature = input ("enter the temperature")
temperature = float (temperature)
if temperature >=25:
    print ("its a warm day")
else:
    print ("its cold outside")
# Out:
# its cold outside

# %%
#password checker
password = input ("please enter your password")
if password != "thomas123":
    print ("please enter your password again")
else:
    print ("welcome back")
# Out:
# welcome back

# %%
#check number sign
num = input ("enter the number")
num = int (num)
if num >0:
    if num <5:
        print ("the number is between 0 and 5")
if num <0:
    print ("the number is negative")
else:
    print ("the number is positive")
# Out:
# the number is negative

# %%
# a simple grade detector code to nest both if and else function
grade = input ("enter your grade")
grade = float (grade)
if grade >=80:
    if grade <=90:
        print ("the grade is A")
if grade >=90:
    if grade <=100:
        print ("the grade is A+")
else:
    print ("grade is satisfactory")
# Out:
# grade is satisfactory

# %%
# a code nesting the "else" function
a = -11
if a > 0:
    if a <10:
        print ("the number is between 0 and 10")
    else:
        print ("the number is not between o and 10")
else:
    print ("the number is negative")
# Out:
# the number is negative

# %%
#check if a number is divisible by 3 and if the number is negative or positive.
num = input ("enter your number")
num = int (num)
if num % 3 == 0:
    print ("the number is divisible by 3")
else:
    print ("the number is not divisible by 3")
if num >2:
    num = int (num)
    print ("the number is positive")
else:
    if num==0:
        print ("the number is equal to 0")
    else:
        print ("the number is negative")
# Out:
# the number is not divisible by 3
# the number is negative

# %%
#check if a user name is valid or invalid
user_name = input ("enter user name")
if user_name == "thomaswanronal":
    print ("welcome to your account")
else:
    print ("the entered user name is wrong")

    if user_name != "thomaswanronal":
        print ("you have used a wrong character")
        print ("you have two more tries")
print ("finished")
# Out:
# welcome to your account
# finished

# %%
#compare two numbers
a = input ("enter the value of a")
b = input ("enter the value of b")
a = int (a)
b = int (b)
if a > 30:
    print ("a is bigger")
else:
    print ("a is not that of a big number")
if b < 20:
    print ("b is smaller")
else: print ("b is a number above 20")
# Out:
# a is not that of a big number
# b is a number above 20
